# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('athlete_events.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# ordenar por edad -> Team -> Sport -> Height
df.sort_values(['Age', 'Team', 'Sport', 'Height'])
# Out:
#             ID                                             Name Sex   Age  \
# 142882   71691                               Dimitrios Loundras   M  10.0
# 140650   70616                                       Liu Luyang   F  11.0
# 43468    22411                       Magdalena Cecilia Colledge   F  11.0
# 237141  118925  Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# 79024    40129                                 Luigina Giavotti   F  11.0
# ...        ...                                              ...  ..   ...
# 166820   83809                                   Francis Mwahza   M   NaN
# 219279  110161                                   Henry Sichalwe   M   NaN
# 237494  119119                                      Asafu Tembo   M   NaN
# 172440   86635                                      Abel Nkhoma   M   NaN
# 22428    11813                              Clyde Cecil Bissett   M   NaN
#
#         Height  Weight                           Team  NOC        Games  Year  \
# ...

# %%
# Cambiar valor Nan en weight por cero
df['Weight'] = df['Weight'].fillna(0)
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     0.0
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     0.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df_medal = df[['Team', 'Medal']].dropna()
df_medal
# Out:
#                   Team   Medal
# 3       Denmark/Sweden    Gold
# 37             Finland  Bronze
# 38             Finland  Bronze
# 40             Finland  Bronze
# 41             Finland  Bronze
# ...                ...     ...
# 271078    Soviet Union  Silver
# 271080    Soviet Union  Bronze
# 271082          Poland  Bronze
# 271102          Russia  Bronze
# 271103          Russia  Silver
#
# [39783 rows x 2 columns]

# %%
# Out:
# Medal
# Bronze    13295
# Gold      13372
# Silver    13116
# Name: Sport, dtype: int64
