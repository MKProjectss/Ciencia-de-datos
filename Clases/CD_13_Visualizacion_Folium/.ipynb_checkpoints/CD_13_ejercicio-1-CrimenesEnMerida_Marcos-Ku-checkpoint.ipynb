# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Ejericicio 1: Crimenes en la ciudad de Mérida (Ficticio)  </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/policia.jpeg" align="middle" style="width:550px"/></td>
# <td>
#
# La Fiscalía General del Estado informó que al día en promedio en Yucatán se registran ocho robos en sus diferentes modalidades, aunque la mayor parte de ellos, cerca del 80 por ciento, ocurre en Mérida.
#
# En esta ciudad, las zonas de mayor incidencia son el Poniente, Sur y Centro.
#
# Aunque los casos más sonados, de mayor cuantía en cuanto al botín y que han llamado la atención de los medios, se dijo que se han registrado en el Norte.
#
# https://www.yucatan.com.mx/merida/merida-el-blanco-principal-de-los-robos
#
#  <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Ejercicio

# %% [markdown]
# <div class="alert alert-success">
#
# Con los datos del archivo "asaltos_yucatan.csv", mostrar en un mapa la ubicación de los delitos en Mérida, de ser posible muestre como _popup_ la categoría.
#
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar el archivo datos/asaltos_yucatan.csv en un DataFrame llamado data
# si es necesario usar la opcion encoding = "ISO-8859-1"
data = pd.read_csv('datos/asaltos_yucatan.csv', encoding = "ISO-8859-1")

# %%
#Mostrar las primeras filas del DataFrame data
data.head(2)
# Out:
#    NumInc Categoria              Descripcion   Ciudad   Direccion        lat  \
# 0       1    asalto  robo objetos personales  Tizimín      Centro  21.142586
# 1       2    asalto  robo objetos personales   Mérida  Calle 53-F  21.074071
#
#         long
# 0 -88.147633
# 1 -89.666229

# %%
data_merida = data[data['Ciudad'] == 'Mérida']
data_merida.head(3)
# Out:
#    NumInc Categoria              Descripcion  Ciudad         Direccion  \
# 1       2    asalto  robo objetos personales  Mérida        Calle 53-F
# 2       3    asalto  robo objetos personales  Mérida  Calle 53 791-803
# 3       4    asalto  robo objetos personales  Mérida  Calle 49 808-796
#
#          lat       long
# 1  21.074071 -89.666229
# 2  21.077830 -89.655865
# 3  21.001845 -89.713986

# %%
# Importar la libreria folium
import folium
# 1 -> categoría
# 5 -> lat
# 6 -> long

# %%
mapa=folium.Map(location=[20.9785, -89.6332],zoom_start=12)
for row in data_merida.values:
    folium.Marker(location=[row[5], row[6]],popup=row[1],
                  tooltip='<strong>Clic para ver</strong>',
                  icon=folium.Icon(color='blue',prefix='fa',icon='people-robbery')).add_to(mapa)
                

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03d7154dd5f81feaf5169c4394d2fda3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03d7154dd5f81feaf5169c4394d2fda3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03d7154dd5f81feaf5169c4394d2fda3 = L.map(
#                 &quot;map_03d7154dd5f81feaf5169c4394d2fda3&quot;,
#                 {
#                     center: [20.9785, -89.6332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7a5792b24c153ad0bf6d36cda27bcdd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_03d7154dd5f81feaf5169c4394d2fda3);
#
#
#             var marker_9bd55d5bfb0bbf0fad9e7678923bbb0a = L.marker(
#                 [21.074071, -89.666229],
#                 {}
#             ).addTo(map_03d7154dd5f81feaf5169c4394d2fda3);
#
#
#             var icon_6b2766c6a1b14dafb8cab8ddea06df91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;people-robbery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9bd55d5bfb0bbf0fad9e7678923bbb0a.setIcon(icon_6b2766c6a1b14dafb8cab8ddea06df91);
#
#
#         var popup_e88ccec0f466f68c8a32e1432c8d72f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5697fa2054cdce2b092ee1cddbe7881 = $(`&lt;div id=&quot;html_b5697fa2054cdce2b092ee1cddbe7881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_e88ccec0f466f68c8a32e1432c8d72f0.setContent(html_b5697fa2054cdce2b092ee1cddbe7881);
#
#
#
#         marker_9bd55d5bfb0bbf0fad9e7678923bbb0a.bindPopup(popup_e88ccec0f466f68c8a32e1432c8d72f0)
#         ;
#
#
#
#
#             marker_9bd55d5bfb0bbf0fad9e7678923bbb0a.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Clic para ver&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0df8618829de70b9efd3129d006c48ca = L.marker(
#                 [21.07783, -89.655865],
#                 {}
#             ).addTo(map_03d7154dd5f81feaf5169c4394d2fda3);
#
#
#             var icon_09275f71c777f226492fbfbd1f34a1e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;people-robbery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0df8618829de70b9efd3129d006c48ca.setIcon(icon_09275f71c777f226492fbfbd1f34a1e8);
#
#
#         var popup_766cc09558f26120122af1a4bb187cb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5926c9aa31f2fcd27bd6a11e63ef8537 = $(`&lt;div id=&quot;html_5926c9aa31f2fcd27bd6a11e63ef8537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_766cc09558f26120122af1a4bb187cb6.setContent(html_5926c9aa31f2fcd27bd6a11e63ef8537);
#
#
#
#         marker_0df8618829de70b9efd3129d006c48ca.bindPopup(popup_766cc09558f26120122af1a4bb187cb6)
#         ;
#
#
#
#
#             marker_0df8618829de70b9efd3129d006c48ca.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;strong&gt;Clic para ver&lt;/strong&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bcda996bd1681f42dd51d1033b654606 = L.marker(
#                 [21.001845, -89.713986],
#                 {}
#             ).addTo(map_03d7154dd5f81feaf5169c4394d2fda3);
#
#
#             var icon_429a2cf3bcda68e4413a1088d3fb4bfc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;people-robbery&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bcda996bd1681f42dd51d1033b654606.setIcon(icon_429a2cf3bcda68e4413a1088d3fb4bfc);
#
#
#         var popup_6a56838edfc4fcd26bec92e0061afe0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df354263f49ed2aa2fa09dc973c2105b = $(`&lt;div id=&quot;html_df354263f49ed2aa2fa09dc973c2105b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;asalto&lt;/div&gt;`)[0];
#                 popup_6a56838edfc4fcd26bec92e0061afe0b.setContent(html_df354263f49ed2aa2fa09dc973c2105b);
