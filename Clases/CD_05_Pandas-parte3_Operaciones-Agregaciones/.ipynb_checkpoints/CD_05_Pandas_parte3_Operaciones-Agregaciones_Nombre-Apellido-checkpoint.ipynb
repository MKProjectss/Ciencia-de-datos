# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/logo_ciencia_datos.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Pandas -Parte 3  </h1></center>
#
# <center><h2 style="font-size:2em;color:#840700">  Pandas - Operaciones y agregaciones  </h4></center>
#
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/pandas3.png" align="left" style="width:500px"/></td>
# <td>
#
# * **Wes McKinney**, empezó a desarrollar Pandas en el año 2008 mientras trabajaba en *AQR Capital* [https://www.aqr.com/] por la necesidad que tenía de una herramienta flexible de alto rendimiento para realizar análisis cuantitativos en datos financieros.
# * Antes de dejar AQR convenció a la administración de la empresa de distribuir esta biblioteca bajo licencia de código abierto.
# * **Pandas** es un acrónimo de **PANel DAta analysiS**
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Operaciones de datos en Pandas

# %% [markdown]
# Parte de las características esenciales de **NumPy** es la capacidad de realizar operaciones rápidas de elementos, tanto con aritmética básica (suma, resta, multiplicación, etc.) como con operaciones más sofisticadas (funciones trigonométricas, funciones exponenciales y logarítmicas, etc.).
# Pandas hereda gran parte de esta funcionalidad de **NumPy** y las _**ufuncs**_ que fueron presentadas en lecciones pasadas son clave para esto.
#
# Sin embargo, **Pandas** incluye un par de características  extras que serán  útiles: para operaciones de negación y trigonométricas, estas _**ufuncs**_  preservarán las etiquetas de índice y columna en la salida, y para operaciones como la suma y la multiplicación, **Pandas** automáticamente *alineará índices*.
# Esto significa que mantener el contexto de los datos y combinar datos de diferentes fuentes, ambas tareas potencialmente propensas a errores con arreglos de **NumPy** sin procesar, se vuelven esencialmente infalibles con **Pandas**.

# %%
poblacion = pd.Series({'Belgica':11.3, 'Francia':64.3, 'Alemania':81.3,
                       'Holanda':16.9, 'Inglaterra':64.9,'Argentina':12.1,'Mexico':103.2})

# %%
data = {'pais': ['Belgica', 'Francia', 'Alemania', 'Holanda', 'Inglaterra','Argentina','Mexico'],
        'poblacion': [11.3, 64.3, 81.3, 16.9, 64.9, 12.1,103.2],
        'area': [30510, 671308, 357050, 41526, 244820,300163,1960573],
        'capital': ['Bruselas', 'Paris', 'Berlin', 'Amsterdam', 'Londres','Buenos Aires','Ciudad de Mexico']}
paises = pd.DataFrame(data)

# %%
#mostrar el dataframe
#paises.head()
paises.tail()
# Out:
#          pais  poblacion     area           capital
# 2    Alemania       81.3   357050            Berlin
# 3     Holanda       16.9    41526         Amsterdam
# 4  Inglaterra       64.9   244820           Londres
# 5   Argentina       12.1   300163      Buenos Aires
# 6      Mexico      103.2  1960573  Ciudad de Mexico

# %% [markdown]
# ## Los "nuevos" conceptos

# %% [markdown]
# Al igual que con loss arreglos de numpy, muchas operaciones son con elementos:

# %%
#Dividir entre 100 los valores de la poblacion en la serie poblacion
poblacion = poblacion/100
poblacion
# Out:
# Belgica       0.113
# Francia       0.643
# Alemania      0.813
# Holanda       0.169
# Inglaterra    0.649
# Argentina     0.121
# Mexico        1.032
# dtype: float64

# %%
#Encontrar la densidad poblacional en el DataFrame paises
paises['densidad'] = paises['poblacion']/paises['area']
paises
# Out:
#          pais  poblacion     area           capital  densidad
# 0     Belgica       11.3    30510          Bruselas  0.000370
# 1     Francia       64.3   671308             Paris  0.000096
# 2    Alemania       81.3   357050            Berlin  0.000228
# 3     Holanda       16.9    41526         Amsterdam  0.000407
# 4  Inglaterra       64.9   244820           Londres  0.000265
# 5   Argentina       12.1   300163      Buenos Aires  0.000040
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053

# %%
#Obtener el logaritmo del valor de la población en el DataFrame countries
np.log(paises['poblacion'])
# Out:
# 0    2.424803
# 1    4.163560
# 2    4.398146
# 3    2.827314
# 4    4.172848
# 5    2.493205
# 6    4.636669
# Name: poblacion, dtype: float64

# %%
#Agregar los valores de la evaluación del logaritmo como una nueva columna "log_poblacion"
paises['log_poblacion'] = np.log(paises['poblacion'])
paises
# Out:
#          pais  poblacion     area           capital  densidad  log_poblacion
# 0     Belgica       11.3    30510          Bruselas  0.000370       2.424803
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 3     Holanda       16.9    41526         Amsterdam  0.000407       2.827314
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 5   Argentina       12.1   300163      Buenos Aires  0.000040       2.493205
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669

# %%
#Mostrar las columnas del  DataFrame paises
paises.columns
# Out:
# Index(['pais', 'poblacion', 'area', 'capital', 'densidad', 'log_poblacion'], dtype='object')

# %%
#Mostrar cuales de ellos tienen una población mayor a los 40 (millones)
paises[paises['poblacion'] > 40]
# Out:
#          pais  poblacion     area           capital  densidad  log_poblacion
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669

# %%
#Mostrar el dataframe solo con las columnas 'pais'  y 'capital'
paises[['pais','capital']]
# Out:
#          pais           capital
# 0     Belgica          Bruselas
# 1     Francia             Paris
# 2    Alemania            Berlin
# 3     Holanda         Amsterdam
# 4  Inglaterra           Londres
# 5   Argentina      Buenos Aires
# 6      Mexico  Ciudad de Mexico

# %% [markdown]
# Cuando requiere de una operación especial en los elementos puede hacerlo con ``apply(OPERACIÓN)``, en donde será necesario definir la  operación a través de la función deseada

# %%
# Agregar una columna que indique si el país es pequeño o grande en población (>50). 
# Defina una función llamada etiqueta_poblacion que regrese la etiqueta

# %%
def etiqueta_poblacion(valor_poblacion):
    if valor_poblacion > 50:
        return 'grande'
    else:
        return 'pequeño'

# %%
paises['poblacion'].apply(etiqueta_poblacion)
# Out:
# 0    pequeño
# 1     grande
# 2     grande
# 3    pequeño
# 4     grande
# 5    pequeño
# 6     grande
# Name: poblacion, dtype: object

# %%
#Agregar la columna etiqueta_poblacional con el resultado de aplicar la funcion etiqueta_poblacion
paises['etiqueta_poblacional'] = paises['poblacion'].apply(etiqueta_poblacion)
paises
# Out:
#          pais  poblacion     area           capital  densidad  log_poblacion  \
# 0     Belgica       11.3    30510          Bruselas  0.000370       2.424803
# 1     Francia       64.3   671308             Paris  0.000096       4.163560
# 2    Alemania       81.3   357050            Berlin  0.000228       4.398146
# 3     Holanda       16.9    41526         Amsterdam  0.000407       2.827314
# 4  Inglaterra       64.9   244820           Londres  0.000265       4.172848
# 5   Argentina       12.1   300163      Buenos Aires  0.000040       2.493205
# 6      Mexico      103.2  1960573  Ciudad de Mexico  0.000053       4.636669
#
#   etiqueta_poblacional
# 0              pequeño
# 1               grande
# 2               grande
# 3              pequeño
# 4               grande
# 5              pequeño
# 6               grande

# %% [markdown]
# También es posible utilizar la función ``lambda``  para realizar operaciones rápidas.

# %%
# Encuentre el número de caracteres de las palabras en la columna capital 
def conteo(capital):
    return len(capital)
paises['capital'].apply(conteo)
# Out:
# 0     8
# 1     5
# 2     6
# 3     9
# 4     7
# 5    12
# 6    16
# Name: capital, dtype: int64

# %%
paises['capital'].apply(lambda capital: len(capital))
# Out:
# 0     8
# 1     5
# 2     6
# 3     9
# 4     7
# 5    12
# 6    16
# Name: capital, dtype: int64

# %% [markdown]
# ## Agregaciones (reducciones)

# %% [markdown]
# Pandas proporciona un amplio conjunto de funciones de _**resumen**_ que operan en diferentes tipos de objetos de pandas (DataFrames y Series) y producen un valor único. Cuando se aplica a un *DataFrame*, el resultado se retorna como una Serie de Pandas (un valor para cada columna).

# %%
#Utilizando la Serie de poblacion, podemos encontrar su promedio usando mean():
poblacion.mean()
# Out:
# 0.5057142857142857

# %%
#Aplicar la mediana al DataFrame paises
paises.median(numeric_only=True)
# Out:
# poblacion            64.300000
# area             300163.000000
# densidad              0.000228
# log_poblacion         4.163560
# dtype: float64

# %%
#Podemos encontrar el pais con con area mas pequeña usando min():
paises['area'].min()
# Out:
# 30510

# %% [markdown]
# La siguiente tabla resume algunas otras agregaciones integradas de Pandas:
#
# | Aggregation              | Description                     |
# |--------------------------|---------------------------------|
# | ``count()``              | Total number of items           |
# | ``first()``, ``last()``  | First and last item             |
# | ``mean()``, ``median()`` | Mean and median                 |
# | ``min()``, ``max()``     | Minimum and maximum             |
# | ``std()``, ``var()``     | Standard deviation and variance |
# | ``mad()``                | Mean absolute deviation         |
# | ``prod()``               | Product of all items            |
# | ``sum()``                | Sum of all items                |
#
# Todos estos son funcionan en *DataFrames* y *Series*.

# %% [markdown]
# Hay una función de muy útil, ``describe()`` , que calcula varios parámetros estadísticos  para cada columna y devuelve el resultado.

# %%
paises.describe()
# Out:
#         poblacion          area  densidad  log_poblacion
# count    7.000000  7.000000e+00  7.000000       7.000000
# mean    50.571429  5.151357e+05  0.000208       3.588078
# std     37.112115  6.729440e+05  0.000150       0.962601
# min     11.300000  3.051000e+04  0.000040       2.424803
# 25%     14.500000  1.431730e+05  0.000074       2.660260
# 50%     64.300000  3.001630e+05  0.000228       4.163560
# 75%     73.100000  5.141790e+05  0.000318       4.285497
# max    103.200000  1.960573e+06  0.000407       4.636669

# %% [markdown]
# # Ejercicios con los datos del Titanic

# %% [markdown]
# Descripción de las columnas :
#
#     Survival - Supervivencia (0 = No; 1 = Si).
#     Pclass - Clase (1 = 1st; 2 = 2nd; 3 = 3rd)
#     Name - Nombre
#     Sex - Sexo
#     Age - Edad
#     Sibsp - Número de hermanos / cónyuges a bordo
#     Parch - Número de padres / niños a bordo
#     Ticket - Número de ticket
#     Fare - Tarifa
#     Cabin - Número de cabina
#     Embarked - Puerto de embarque (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
#Utilizar el archivo datos/titanic.csv
df = pd.read_csv('datos/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#muestre las primeras líneas del DataFrame
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
#muestre las ultimas líneas  del DataFrame 
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
#Obtenga el número de filas y columnas
df.shape
# Out:
# (891, 12)

# %%
#Muestre los histogramas de las variables numericas 
df.hist()
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li> Seleccione todas las filas para pasajeros masculinos y calcule la edad media de esos pasajeros. Hacer lo mismo con las pasajeras.</li>
# </ul>
# </div>

# %%
#Se puede definir un nuevo DataFrame solamente con elementos "male" en la columna de Sex
df_male = df[df['Sex'] == 'male']
df_male
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   NaN        S
# 4    35.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  27.0      0      0            211536  13.0000   NaN        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
#Se encuentra la media utilizando el nuevo DataFrame
df_male['Age'].mean()
# Out:
# 30.72664459161148

# %%
df[df['Sex'] == 'male']['Age'].mean()
# Out:
# 30.72664459161148

# %%
#Redondeando el valor anterior a dos decimales
round(df_male['Age'].mean(), 2)
# Out:
# 30.73

# %%
#Para el segundo requerimiento se puede realizar todo en una sola linea
df[df['Sex'] == 'female']['Age'].mean()
# Out:
# 27.915708812260537

# %%
#Redondeando el valor anterior a dos decimales
round(df[df['Sex'] == 'female']['Age'].mean(), 2)
# Out:
# 27.92

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li>¿Cuántos pasajeros mayores de 70 estaban en el Titanic?</li>
# </ul>
# </div>

# %%
#Se puede aplicar una máscara para seleccionar solamente a los pasajeros mayores a 70 años, 
#Al DataFrame resultante se cuentan las filas usando len()
len(df[df['Age'] > 70])
# Out:
# 5

# %%
#Un segundo método es aplicar la función sum() a la máscara booleana, 
#Solamente se sumaran los elementos True

# %%
(df['Age'] > 70).sum()
# Out:
# 5

# %%
df[df['Age'] > 70]['Age'].count()
# Out:
# 5

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li>¿Seleccionar los pasajeros que tienen entre 30 y 40 años?</li>
# </ul>
# </div>

# %%
df[(df['Age'] > 30) & (df['Age'] < 40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 13            14         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 867          868         0       1
# 872          873         0       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 4        0    373450   8.0500          NaN        S
# 13       5    347082  31.2750          NaN        S
# 18       0    345763  18.0000          NaN        S
# ..     ...       ...      ...          ...      ...
# 867      0  PC 17590  50.4958          A24        S
# 872      0       695   5.0000  B51 B53 B55        S
# 881      0    349257   7.8958          NaN        S
# 885      5    382652  29.1250          NaN        Q
# 890      0    370376   7.7500          NaN        Q
#
# [142 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#  <ul>
#   <li> Divida la columna 'Name' y  extraiga la primera parte (el apellido) y agréguela como nueva columna 'Surname', para el resto del nombre agregarlo en una nueva columna llamada 'R-name'</li>
# </ul>
#
# <br>
# </div>

# %%
#Para la columna Surname se definirá una nueva función
def dividir(name):
    name = name.split(' ')

# %%
#Aplicando la funcion en el DataFrame

# %%
#Para la columna R-name utilizaremos una función lambda

# %% [markdown]
# <div class="alert alert-info">
#
# <b>EJERCICIO</b>:
#
#
# Agregar una nueva columna llamada “Categoria”, la cual tendrá como elementos las siguientes etiquetas segun el valor del ticket:
#
# * Si el valor es menor a 20, L -- Ticket -- Pclass -- Fare
# * Si el valor es mayor o igual a 20 pero menor a 50, M -- Ticket -- Pclass -- Fare
# * Si el valor es mayor o igual 50, H -- Ticket -- Pclass -- Fare
#
# Ejemplo:
# L--A/5 21171--3--7.25
#
# H--PC 17599--1--71.2833
#
# L--STON/O2. 3101282--3--7.925
#
# </div>

# %%
def tag(campos):
    if campos[0] < 20:
        return f'L -- {campos[1]} -- {str(campos[2])} -- {str(campos[0])}'
    elif (campos[0] >= 20) & (campos[0] < 50):
        return f'M -- {campos[1]} -- {str(campos[2])} -- {str(campos[0])}'
    elif campos[0] >= 50:
        return f'H -- {(campos[1])} -- {str(campos[2])} -- {str(campos[0])}'

df['Categoria']= df[ ['Fare','Ticket','Pclass'] ].apply(tag, axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
#                              Categoria
# 0          L -- A/5 21171 -- 3 -- 7.25
# 1        H -- PC 17599 -- 1 -- 71.2833
# 2  L -- STON/O2. 3101282 -- 3 -- 7.925
# 3             H -- 113803 -- 1 -- 53.1
# 4             L -- 373450 -- 3 -- 8.05

# %% [markdown]
# # Parte 1

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 1 </b>:
#
#
# Encontrar el promedio de edad para los pasajeros de cada clase, así como su desviación estándar.
#
#
# </div>

# %%
# Clase 1
print(f'''-----------------------------
Clase 1
-----------------------------
Promedio: {round(df[df['Pclass'] == 1]['Age'].mean(), 4)}
Desciación estandar: {round(df[df['Pclass'] == 1]['Age'].std(), 4)}
-----------------------------
-----------------------------
Clase 2
-----------------------------
Promedio: {round(df[df['Pclass'] == 2]['Age'].mean(), 4)}
Desciación estandar: {round(df[df['Pclass'] == 2]['Age'].std(), 4)}
-----------------------------
-----------------------------
Clase 3
-----------------------------
Promedio: {round(df[df['Pclass'] == 3]['Age'].mean(), 4)}
Desciación estandar: {round(df[df['Pclass'] == 3]['Age'].std(), 4)}
-----------------------------''')
# Out:
# -----------------------------
# Clase 1
# -----------------------------
# Promedio: 38.2334
# Desciación estandar: 14.8029
# -----------------------------
# -----------------------------
# Clase 2
# -----------------------------
# Promedio: 29.8776
# Desciación estandar: 14.0011
# -----------------------------
# -----------------------------
# Clase 3
# -----------------------------
# Promedio: 25.1406
# Desciación estandar: 12.4954
# -----------------------------

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 2</b>:
#
# Encontrar el número total de pasajeros por cada punto de embarcación.
#
# </div>

# %%
print(f'''-----------------------------------
Numero de pasajeros por embarcación
-----------------------------------
Cherbourg: {len(df[df['Embarked'] == 'C'])}
Queenstown: {len(df[df['Embarked'] == 'Q'])}
Southampton: {len(df[df['Embarked'] == 'S'])}
-----------------------------------''')
# Out:
# -----------------------------------
# Numero de pasajeros por embarcación
# -----------------------------------
# Cherbourg: 168
# Queenstown: 77
# Southampton: 644
# -----------------------------------

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 3</b>:
#
# a) Encontrar el promedio de edad de los pasajeros que sobrevivieron.
#
# b) Encontrar el promedio de edad de los hombres que sobrevivieron
#
# c) Encontrar el promedio de edad de las mujeres que sobrevivieron
# </div>

# %%
# a) Encontrar el promedio de edad de los pasajeros que sobrevivieron.
df[df['Survived'] == 1]['Age'].mean()
# Out:
# 28.343689655172415

# %%
# b) Encontrar el promedio de edad de los hombres que sobrevivieron
df[(df['Sex'] == 'male') & (df['Survived'] == 1)]['Age'].mean()
# Out:
# 27.276021505376345

# %%
# c) Encontrar el promedio de edad de las mujeres que sobrevivieron
df[(df['Sex'] == 'female') & (df['Survived'] == 1)]['Age'].mean()
# Out:
# 28.84771573604061

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 4</b>:
#
# ¿Cuál fue el número de sobrevivientes mujeres  mayores a 40 años? ¿Cuál era la probabilidad de supervivencia para  mujeres mayores a 40 años?
#
# </div>

# %%
# Número total de mujeres mayores a 40 años
female_mayor_40 = len(df[(df['Sex'] == 'female') & (df['Age'] > 40)])
female_mayor_40
# Out:
# 48

# %%
# Numero de supervivientes mujeres mayores a 40 años
female_mayor_40_survived = len(df[(df['Sex'] == 'female') & (df['Age'] > 40) & (df['Survived'] == 1)])
female_mayor_40_survived
# Out:
# 37

# %%
print(f'Probabilidad de supervivencia de mujeres mayores a 40 años: {(female_mayor_40_survived/female_mayor_40)*100}%')
# Out:
# Probabilidad de supervivencia de mujeres mayores a 40 años: 77.08333333333334%

# %% [markdown]
# <div class="alert alert-success">
#
# <b>EJERCICIO 5</b>:
#
#
# Agregar una nueva columna llamada “Status”, la cual tendrá como elementos las siguientes etiquetas segun la edad:
#
# * Adult-male, si el pasajero es hombre y mayor a 21 años
# * Adult-female, si el pasajero es mujer  y mayor a 21 años
# * Minor-male, si el pasajero es hombre y su edad es menor o igual  a 21 años
# * Minor-female, si el pasajero es mujer y  su edad es menor o igual a 21 años
#
# </div>

# %%
def tag(campos):
    if campos[0] == 'male':
        if campos[1] > 21:
            return 'Adult-male'
        else:
            return 'Minor-male'
    elif campos[0] == 'female':
        if campos[1] > 21:
            return 'Adult-female'
        else:
            return 'Minor-female'
        

df['Status']= df[ ['Sex','Age'] ].apply(tag, axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  \
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
#                                Categoria        Status
# 0            L -- A/5 21171 -- 3 -- 7.25    Adult-male
# 1          H -- PC 17599 -- 1 -- 71.2833  Adult-female
# 2    L -- STON/O2. 3101282 -- 3 -- 7.925  Adult-female
# 3               H -- 113803 -- 1 -- 53.1  Adult-female
# 4               L -- 373450 -- 3 -- 8.05    Adult-male
# ..                                   ...           ...
# 886             L -- 211536 -- 2 -- 13.0    Adult-male
# 887             M -- 112053 -- 1 -- 30.0  Minor-female
# 888        M -- W./C. 6607 -- 3 -- 23.45  Minor-female
# 889             M -- 111369 -- 1 -- 30.0    Adult-male
# 890             L -- 370376 -- 3 -- 7.75    Adult-male
#
# [891 rows x 14 columns]

# %% [markdown]
# # Parte 2:  Escuelas de Jalisco
# Utilizar los datos del archivo "cct_estadistica_short.csv" para realizar los siguientes ejercicios

# %%
#Leer los datos 
df = pd.read_csv('datos/cct_estadistica_short.csv',  encoding='latin1')

# %%
#Desplegar parte del dataframe
df.head()
# Out:
#      CLAVE CT                    NOM TURNO                  NOMBRE CT  \
# 0  14DPR3480S                   VESPERTINO  MIGUEL HIDALGO Y COSTILLA
# 1  14DPR2780I                     MATUTINO        CONSTITUCION DEL 57
# 2  14DPR1553G  CONTINUO (JORNADA AMPLIADA)  MIGUEL HIDALGO Y COSTILLA
# 3  14SES0104Q                     MATUTINO               NIOS HEROES
# 4  14EJN0826I                   VESPERTINO        EVA GONZALEZ BLANCO
#
#                         DOMICILIO  LOCALIDAD INEGI       NOMBRE LOCALIDAD  \
# 0                    RIO SANTIAGO                1        TIZAPAN EL ALTO
# 1                        CONOCIDO               54         MESA DE MENDEZ
# 2                        CONOCIDO               31                DOLORES
# 3              ALVARO OBREGON 115              280  SANTA MARIA DEL VALLE
# 4  MARCELINO GARCIA BARRAGAN 1954                1            GUADALAJARA
#
#   NOMBRE COLONIA  MUNICIPIO NOMBRE MUNICIPIO SOSTENIMIENTO  ... DOCENTES  \
# 0     ATRACADERO         96  TIZAPAN EL ALTO  FEDERALIZADO  ...        6
# 1              0         16          AYOTLAN  FEDERALIZADO  ...        1
# 2              0         25         COLOTLAN  FEDERALIZADO  ...        3
# 3              0          8          ARANDAS    PARTICULAR  ...        9
# 4              0         39      GUADALAJARA       ESTATAL  ...        5
#
#   GRUPOS  DOCENETE EDUCACION FISICA  DOCENTE ACTIVIDADES ARTISTICAS  \
# 0      6                          1                               0
# 1      1                          0                               0
# 2      3                          1                               0
# 3      3                          1                               1
# 4      5                          1                               1
#
#    DOCENTE ACTIVIDADES TECNONOLOGICAS  DOCENTE DE IDIOMAS  \
# 0                                   0                   0
# 1                                   0                   0
# 2                                   0                   0
# 3                                   1                   0
# 4                                   0                   0
#
#    PERSONAL DE ADMINISTRATIVO Y SERVICIOS  DIRECTOR CON GRUPO  \
# 0                                       0                   0
# 1                                       0                   1
# 2                                       0                   1
# 3                                       1                   1
# 4                                       6                   0
#
#    DIRECTOR SIN GRUPO  TOTAL DE PERSONAL
# 0                   1                  8
# 1                   0                  1
# 2                   0                  4
# 3                   0                 10
# 4                   1                 14
#
# [5 rows x 43 columns]

# %%
#Resumen estadistico de los campos
df.describe()
# Out:
#        LOCALIDAD INEGI    MUNICIPIO   HOMBRES 1¡   MUJERES 1¡     TOTAL 1¡  \
# count      3205.000000  3205.000000  3205.000000  3205.000000  3205.000000
# mean         68.188456    69.267395    13.990640    13.320437    27.311076
# std         352.396926    36.099546    28.627149    25.183012    52.093390
# min           1.000000     1.000000     0.000000     0.000000     0.000000
# 25%           1.000000    39.000000     0.000000     0.000000     1.000000
# 50%           3.000000    68.000000     4.000000     4.000000     7.000000
# 75%          52.000000   100.000000    15.000000    14.000000    29.000000
# max        9503.000000   125.000000   565.000000   221.000000   565.000000
#
#         HOMBRES 2¡   MUJERES 2¡     TOTAL 2¡   HOMBRES 3¡   MUJERES 3¡  ...  \
# count  3205.000000  3205.000000  3205.000000  3205.000000  3205.000000  ...
# mean     17.495476    16.978783    34.474259    16.887676    16.520437  ...
# std      24.999908    24.167297    47.835989    23.292725    22.591801  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       3.000000     2.000000     5.000000     2.000000     2.000000  ...
# 50%       9.000000     9.000000    18.000000     9.000000     9.000000  ...
# 75%      23.000000    22.000000    44.000000    23.000000    22.000000  ...
# max     427.000000   221.000000   427.000000   422.000000   201.000000  ...
#
#           DOCENTES       GRUPOS  DOCENETE EDUCACION FISICA  \
# count  3205.000000  3205.000000                3205.000000
# mean      5.691108     4.651482                   0.453978
# std       7.223604     4.293962                   0.702337
# min       0.000000     1.000000                   0.000000
# 25%       1.000000     1.000000                   0.000000
# 50%       3.000000     3.000000                   0.000000
# 75%       6.000000     6.000000                   1.000000
# max      70.000000    29.000000                   6.000000
#
#        DOCENTE ACTIVIDADES ARTISTICAS  DOCENTE ACTIVIDADES TECNONOLOGICAS  \
# count                     3205.000000                         3205.000000
# mean                         0.239938                            0.227145
# std                          0.568769                            0.900589
# min                          0.000000                            0.000000
# 25%                          0.000000                            0.000000
# 50%                          0.000000                            0.000000
# 75%                          0.000000                            0.000000
# max                          7.000000                           17.000000
#
#        DOCENTE DE IDIOMAS  PERSONAL DE ADMINISTRATIVO Y SERVICIOS  \
# count         3205.000000                             3205.000000
# mean             0.125117                                1.866459
# std              0.652190                                4.150073
# min              0.000000                                0.000000
# 25%              0.000000                                0.000000
# 50%              0.000000                                1.000000
# 75%              0.000000                                2.000000
# max             15.000000                               51.000000
#
#        DIRECTOR CON GRUPO  DIRECTOR SIN GRUPO  TOTAL DE PERSONAL
# count         3205.000000         3205.000000        3205.000000
# mean             0.409048            0.488924           8.658658
# std              0.552132            0.588820          11.393876
# min              0.000000            0.000000           0.000000
# 25%              0.000000            0.000000           1.000000
# 50%              0.000000            0.000000           5.000000
# 75%              1.000000            1.000000          11.000000
# max             10.000000            7.000000         122.000000
#
# [8 rows x 33 columns]

# %%
#Mostrar los nombres de las columnas del dataframe
df.columns
# Out:
# Index(['CLAVE CT', 'NOM TURNO', 'NOMBRE CT', 'DOMICILIO', 'LOCALIDAD INEGI',
#        ' NOMBRE LOCALIDAD', 'NOMBRE COLONIA', 'MUNICIPIO', 'NOMBRE MUNICIPIO',
#        'SOSTENIMIENTO', 'NIVEL', 'PROGRAMA', 'HOMBRES 1¡', 'MUJERES 1¡',
#        'TOTAL 1¡', 'HOMBRES 2¡', 'MUJERES 2¡', 'TOTAL 2¡', 'HOMBRES 3¡',
#        'MUJERES 3¡', 'TOTAL 3¡', 'HOMBRES 4¡', 'MUJERES 4¡', 'TOTAL 4¡',
#        'HOMBRES 5¡', 'MUJERES 5¡', 'TOTAL 5¡', 'HOMBRES 6¡', 'MUJERES 6¡',
#        'TOTAL 6¡', 'HOMBRES TOTAL', 'MUJERES TOTAL', 'MATRICULA TOTAL',
#        'DOCENTES', 'GRUPOS', 'DOCENETE EDUCACION FISICA',
#        'DOCENTE ACTIVIDADES ARTISTICAS', 'DOCENTE ACTIVIDADES TECNONOLOGICAS',
#        'DOCENTE DE IDIOMAS', 'PERSONAL DE ADMINISTRATIVO Y SERVICIOS',
#        'DIRECTOR CON GRUPO', 'DIRECTOR SIN GRUPO', 'TOTAL DE PERSONAL'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 6 </b>:
#  <ul>
#   <li> Encuentre el número de estudiantes por nivel educativo (PRIMARIA, SECUNDARIA y BACHILLERATO). </li>
# </ul>
#
# </div>

# %%
print(f'''-----------------------------------------
Numero de estudiantes por nivel educativo
-----------------------------------------
- Primaria: {sum(df[df['NIVEL'] == 'PRIMARIA']['MATRICULA TOTAL'])}
- Secundaria: {sum(df[df['NIVEL'] == 'SECUNDARIA']['MATRICULA TOTAL'])}
- Bachillerato: {sum(df[df['NIVEL'] == 'BACHILLERATO']['MATRICULA TOTAL'])}
-----------------------------------------''')
# Out:
# -----------------------------------------
# Numero de estudiantes por nivel educativo
# -----------------------------------------
# - Primaria: 196298
# - Secundaria: 102051
# - Bachillerato: 29768
# -----------------------------------------

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 7 </b>:
#  <ul>
#   <li>  Encuentre el número de estudiantes hombres y mujeres por nivel educativo (PRIMARIA, SECUNDARIA y BACHILLERATO).    </li>
# </ul>
#
# </div>

# %%
print(f'''-------------------
Nivel primaria:
- Hombres: {sum(df[df['NIVEL'] == 'PRIMARIA']['HOMBRES TOTAL'])}
- Mujeres: {sum(df[df['NIVEL'] == 'PRIMARIA']['MUJERES TOTAL'])}
-------------------
Nivel secundaria
- Hombres: {sum(df[df['NIVEL'] == 'SECUNDARIA']['HOMBRES TOTAL'])}
- Mujeres: {sum(df[df['NIVEL'] == 'SECUNDARIA']['MUJERES TOTAL'])}
-------------------
Nivel bachillerato
- Hombres: {sum(df[df['NIVEL'] == 'BACHILLERATO']['HOMBRES TOTAL'])}
- Mujeres: {sum(df[df['NIVEL'] == 'BACHILLERATO']['MUJERES TOTAL'])}
-------------------
      ''')
# Out:
# -------------------
# Nivel primaria:
# - Hombres: 99972
# - Mujeres: 96326
# -------------------
# Nivel secundaria
# - Hombres: 51867
# - Mujeres: 50184
# -------------------
# Nivel bachillerato
# - Hombres: 15453
# - Mujeres: 14315
# -------------------

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 8 </b>:
#  <ul>
#   <li>  ¿Cuál es el promedio de docentes por nivel educativo?  </li>
# </ul>
#
# </div>

# %%
df.columns
# Out:
# Index(['CLAVE CT', 'NOM TURNO', 'NOMBRE CT', 'DOMICILIO', 'LOCALIDAD INEGI',
#        ' NOMBRE LOCALIDAD', 'NOMBRE COLONIA', 'MUNICIPIO', 'NOMBRE MUNICIPIO',
#        'SOSTENIMIENTO', 'NIVEL', 'PROGRAMA', 'HOMBRES 1¡', 'MUJERES 1¡',
#        'TOTAL 1¡', 'HOMBRES 2¡', 'MUJERES 2¡', 'TOTAL 2¡', 'HOMBRES 3¡',
#        'MUJERES 3¡', 'TOTAL 3¡', 'HOMBRES 4¡', 'MUJERES 4¡', 'TOTAL 4¡',
#        'HOMBRES 5¡', 'MUJERES 5¡', 'TOTAL 5¡', 'HOMBRES 6¡', 'MUJERES 6¡',
#        'TOTAL 6¡', 'HOMBRES TOTAL', 'MUJERES TOTAL', 'MATRICULA TOTAL',
#        'DOCENTES', 'GRUPOS', 'DOCENETE EDUCACION FISICA',
#        'DOCENTE ACTIVIDADES ARTISTICAS', 'DOCENTE ACTIVIDADES TECNONOLOGICAS',
#        'DOCENTE DE IDIOMAS', 'PERSONAL DE ADMINISTRATIVO Y SERVICIOS',
#        'DIRECTOR CON GRUPO', 'DIRECTOR SIN GRUPO', 'TOTAL DE PERSONAL'],
#       dtype='object')

# %%
print(f'''----------------------------------------
Promedio de docentes por nivel educativo
----------------------------------------
- Preescolar: {sum(df[df['NIVEL'] == 'PREESCOLAR']['DOCENTES'])/len(df[df['NIVEL'] == 'PREESCOLAR'])}
- Primaria: {sum(df[df['NIVEL'] == 'PRIMARIA']['DOCENTES'])/len(df[df['NIVEL'] == 'PRIMARIA'])}
- Secundaria: {sum(df[df['NIVEL'] == 'SECUNDARIA']['DOCENTES'])/len(df[df['NIVEL'] == 'SECUNDARIA'])}
- Bachillerato: {sum(df[df['NIVEL'] == 'BACHILLERATO']['DOCENTES'])/len(df[df['NIVEL'] == 'BACHILLERATO'])}''')
# Out:
# ----------------------------------------
# Promedio de docentes por nivel educativo
# ----------------------------------------
# - Preescolar: 2.6612529002320184
# - Primaria: 5.662754303599374
# - Secundaria: 12.412371134020619
# - Bachillerato: 10.348993288590604

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 9 </b>:
#  <ul>
#   <li>   Encuentre el porcentaje de  escuelas Particulares </li>
# </ul>
#
# </div>

# %%
print(f'''--------------------------------------------
Porcentaje de escuelas particulares: {round((len(df[df['SOSTENIMIENTO'] == 'PARTICULAR'])/len(df['SOSTENIMIENTO']))*100, 2)}%
--------------------------------------------''')
# Out:
# --------------------------------------------
# Porcentaje de escuelas particulares: 17.25%
# --------------------------------------------

# %% [markdown]
# <div class="alert alert-success">
#     <b>EJERCICIO 10 </b>:
#  <ul>
#   <li>   Encuentre el porcentaje de  escuelas PREESCOLAR, PRIMARIA,  SECUNDARIA y BACHILLERATO  </li>
# </ul>
#
# </div>

# %%
print(f'''-----------------------------------------
Porcentaje de escuelas
-----------------------------------------
- Preescolar: {round((len(df[df['NIVEL'] == 'PREESCOLAR'])/len(df['NIVEL']))*100, 2)}%
- Primaria: {round((len(df[df['NIVEL'] == 'PRIMARIA'])/len(df['NIVEL']))*100, 2)}%
- Secundaria: {round((len(df[df['NIVEL'] == 'SECUNDARIA'])/len(df['NIVEL']))*100, 2)}%
- Bachillerato: {round((len(df[df['NIVEL'] == 'BACHILLERATO'])/len(df['NIVEL']))*100, 2)}%
-----------------------------------------''')
# Out:
# -----------------------------------------
# Porcentaje de escuelas
# -----------------------------------------
# - Preescolar: 40.34%
# - Primaria: 39.88%
# - Secundaria: 15.13%
# - Bachillerato: 4.65%
# -----------------------------------------
